# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime
import scipy.stats as stats
import warnings;
warnings.filterwarnings('ignore');

# %%
# Locate the resource folder with csv files and output folder to store charts
resources_folder = "./Resources"
output_folder = "./output_figures"

# %%
# Read in cost of living data
cost_of_living_df = pd.read_csv(f"{resources_folder}/cost_of_living_data.csv",index_col="City",
                                encoding="utf-8")
cost_of_living_df.columns
# Out:
# Index(['Meal, Inexpensive Restaurant ',
#        'Meal for 2 People, Mid-range Restaurant, Three-course Meal, Inexpensive Restaurant',
#        'McMeal at McDonalds (or Equivalent Combo Meal)',
#        'Domestic Beer (1 pint draught)', 'Imported Beer (12 oz small bottle)',
#        'Cappuccino (regular)', 'Coke/Pepsi (12 oz small bottle)',
#        'Water (12 oz small bottle)', 'Milk (regular), (1 gallon)',
#        'Loaf of Fresh White Bread (1 lb)', 'Rice (white), (1 lb) ',
#        'Eggs (regular) (12)', 'Local Cheese (1 lb)',
#        'Chicken Breasts (Boneless, Skinless), (1 lb)',
#        'Beef Round (1 lb) (or Equivalent Back Leg Red Meat)', 'Apples (1 lb)',
#        'Banana (1 lb)', 'Oranges (1 lb)', 'Tomato (1 lb)', 'Potato (1 lb)',
#        'Onion (1 lb)', 'Lettuce (1 head)', 'Water (1.5 liter bottle)',
#        'Bottle of Wine (Mid-Range)', 'Domestic Beer (0.5 liter bottle)',
#        'Imported Beer (12 oz small bottle).1', 'Cigarettes 20 Pack (Marlboro)',
#        'One-way Ticket (Local Transport)', 'Monthly Pass (Regular Price)',
#        'Taxi Start (Normal Tariff)', 'Taxi 1 mile (Normal Tariff)',
#        'Taxi 1hour Waiting (Normal Tariff)', 'Gasoline (1 gallon)',
#        'Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car)',
#        'Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)',
#        'Basic (Electricity, Heating, Cooling, Water, Garbage) for 915 sq ft Apartment',
#        '1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans)',
#        'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)',
#        'Fitness Club, Monthly Fee for 1 Adult ',
#        'Tennis Court Rent (1 Hour on Weekend)',
#        'Cinema, International Release, 1 Seat',
#        'Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child ',
#        'International Primary School, Monthly for 1 Child',
#        '1 Pair of Jeans (Levis 501 Or Similar)',
#        '1 Summer Dress in a Chain Store (Zara, H&M, ...) ',
#        '1 Pair of Nike Running Shoes (Mid-Range)',
#        '1 Pair of Men Leather Business Shoes',
#        'Apartment (1 bedroom) in City Centre',
#        'Apartment (1 bedroom) Outside of Centre',
#        'Apartment (3 bedrooms) in City Centre',
#        'Apartment (3 bedrooms) Outside of Centre',
#        'Price per Square Feet to Buy Apartment in City Centre',
#        'Price per Square Feet to Buy Apartment Outside of Centre',
#        'Average Monthly Net Salary (After Tax)',
#        'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate'],
#       dtype='object')

# %%
# sort the city names
cost_of_living_df.sort_index(axis="index",inplace=True)
cost_of_living_df
# Out:
#                Meal, Inexpensive Restaurant   \
# City
# Atlanta                                 15.0
# Boston                                  15.0
# Chicago                                 15.0
# Houston                                 15.0
# Los Angeles                             15.0
# New York City                           20.0
# Philadelphia                            15.0
# San Francisco                           15.0
# Seattle                                 15.0
# Washington DC                           16.0
#
#                Meal for 2 People, Mid-range Restaurant, Three-course Meal, Inexpensive Restaurant  \
# City
# Atlanta                                                     50.0
# Boston                                                      69.0
# Chicago                                                     65.0
# Houston                                                     65.0
# Los Angeles                                                 70.0
# New York City                                               80.0
# Philadelphia                                                60.0
# San Francisco                                               80.0
# Seattle                                                     62.5
# Washington DC                                               72.5
#
#                McMeal at McDonalds (or Equivalent Combo Meal)  \
# City
# Atlanta                                                  7.00
# Boston                                                   8.00
# Chicago                                                  7.00
# Houston                                                  7.29
# Los Angeles                                              7.50
# New York City                                            9.00
# Philadelphia                                             7.00
# San Francisco                                            8.00
# Seattle                                                  9.00
# Washington DC                                            8.00
#
#                Domestic Beer (1 pint draught)  \
# City
# Atlanta                                   5.0
# Boston                                    6.0
# Chicago                                   5.0
# Houston                                   5.0
# Los Angeles                               6.0
# New York City                             7.0
# Philadelphia                              5.0
# San Francisco                             6.0
# Seattle                                   6.0
# Washington DC                             6.0
#
#                Imported Beer (12 oz small bottle)  Cappuccino (regular)  \
# City
# Atlanta                                      6.00                  3.94
# Boston                                       7.21                  3.88
# Chicago                                      6.00                  4.09
# Houston                                      6.00                  4.23
# Los Angeles                                  7.00                  4.42
# New York City                                8.00                  4.38
# Philadelphia                                 6.00                  3.92
# San Francisco                                7.00                  4.45
# Seattle                                      6.00                  4.27
# Washington DC                                8.00                  4.21
#
#                Coke/Pepsi (12 oz small bottle)  Water (12 oz small bottle)  \
# City
# Atlanta                                   1.79                        1.60
# Boston                                    1.86                        1.49
# Chicago                                   1.82                        1.61
# Houston                                   1.80                        1.45
# Los Angeles                               2.32                        1.79
# New York City                             2.07                        1.69
# Philadelphia                              1.83                        1.22
# San Francisco                             2.27                        1.93
# Seattle                                   1.93                        1.53
# Washington DC                             1.95                        1.70
#
#                Milk (regular), (1 gallon)  Loaf of Fresh White Bread (1 lb)  \
# City
# Atlanta                              3.14                              2.47
# Boston                               3.20                              2.49
# Chicago                              2.75                              2.36
# Houston                              2.96                              2.00
# Los Angeles                          3.99                              2.77
# New York City                        4.43                              3.46
# Philadelphia                         4.10                              2.98
# San Francisco                        4.25                              3.44
# Seattle                              3.18                              2.90
# Washington DC                        3.42                              3.28
#
#                                                   ...                                      \
# City                                              ...
# Atlanta                                           ...
# Boston                                            ...
# Chicago                                           ...
# Houston                                           ...
# Los Angeles                                       ...
# New York City                                     ...
# Philadelphia                                      ...
# San Francisco                                     ...
# Seattle                                           ...
# Washington DC                                     ...
#
#                1 Pair of Nike Running Shoes (Mid-Range)  \
# City
# Atlanta                                           73.26
# Boston                                            77.68
# Chicago                                           78.20
# Houston                                           69.03
# Los Angeles                                       79.47
# New York City                                     87.87
# Philadelphia                                      72.69
# San Francisco                                     86.29
# Seattle                                           82.16
# Washington DC                                     78.46
#
#                1 Pair of Men Leather Business Shoes  \
# City
# Atlanta                                       91.91
# Boston                                        95.19
# Chicago                                      113.53
# Houston                                       87.91
# Los Angeles                                  107.57
# New York City                                128.32
# Philadelphia                                  88.17
# San Francisco                                136.29
# Seattle                                      114.40
# Washington DC                                106.96
#
#                Apartment (1 bedroom) in City Centre  \
# City
# Atlanta                                     1474.70
# Boston                                      2367.32
# Chicago                                     1741.03
# Houston                                     1341.52
# Los Angeles                                 2133.97
# New York City                               3122.07
# Philadelphia                                1577.48
# San Francisco                               3366.36
# Seattle                                     1981.92
# Washington DC                               2210.95
#
#                Apartment (1 bedroom) Outside of Centre  \
# City
# Atlanta                                        1053.33
# Boston                                         1756.95
# Chicago                                        1125.29
# Houston                                         883.06
# Los Angeles                                    1633.41
# New York City                                  2003.74
# Philadelphia                                   1026.79
# San Francisco                                  2736.89
# Seattle                                        1521.60
# Washington DC                                  1668.57
#
#                Apartment (3 bedrooms) in City Centre  \
# City
# Atlanta                                      2684.62
# Boston                                       4048.29
# Chicago                                      3257.66
# Houston                                      2542.16
# Los Angeles                                  3860.91
# New York City                                6468.45
# Philadelphia                                 2844.05
# San Francisco                                5743.88
# Seattle                                      3599.90
# Washington DC                                3995.65
#
#                Apartment (3 bedrooms) Outside of Centre  \
# City
# Atlanta                                         1707.14
# Boston                                          2765.18
# Chicago                                         1982.69
# Houston                                         1637.62
# Los Angeles                                     2922.74
# New York City                                   3511.42
# Philadelphia                                    1608.25
# San Francisco                                   4356.71
# Seattle                                         2562.26
# Washington DC                                   2863.50
#
#                Price per Square Feet to Buy Apartment in City Centre  \
# City
# Atlanta                                                   300.04
# Boston                                                    922.44
# Chicago                                                   338.02
# Houston                                                   191.79
# Los Angeles                                               690.17
# New York City                                            1279.28
# Philadelphia                                              303.66
# San Francisco                                            1163.16
# Seattle                                                   654.13
# Washington DC                                             558.93
#
#                Price per Square Feet to Buy Apartment Outside of Centre  \
# City
# Atlanta                                                   129.82
# Boston                                                    393.84
# Chicago                                                   183.54
# Houston                                                   100.56
# Los Angeles                                               417.08
# New York City                                             574.65
# Philadelphia                                              105.74
# San Francisco                                             893.36
# Seattle                                                   402.16
# Washington DC                                             277.61
#
#                Average Monthly Net Salary (After Tax)  \
# City
# Atlanta                                       3746.22
# Boston                                        4218.65
# Chicago                                       3860.47
# Houston                                       3498.15
# Los Angeles                                   3824.32
# New York City                                 4546.67
# Philadelphia                                  3108.73
# San Francisco                                 6145.51
# Seattle                                       4631.83
# Washington DC                                 4806.44
#
#                Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate
# City
# Atlanta                                                     4.27
# Boston                                                      4.28
# Chicago                                                     4.32
# Houston                                                     4.25
# Los Angeles                                                 4.37
# New York City                                               4.35
# Philadelphia                                                4.31
# San Francisco                                               4.32
# Seattle                                                     4.36
# Washington DC                                               4.27
#
# [10 rows x 55 columns]

# %%
# Read in Glassdoor job title salary data
glassdoor_job_title_df = pd.read_csv(f"{resources_folder}/glassdoor_job_title_data.csv",
                                encoding="utf-8")
glassdoor_job_title_df.head()
# Out:
#       Metro Dimension Type    Month           Dimension          Measure  \
# 0  National      Job Title  2017-06   Software Engineer  Median Base Pay
# 1  National      Job Title  2017-06  Programmer Analyst  Median Base Pay
# 2  National      Job Title  2017-06          Consultant  Median Base Pay
# 3  National      Job Title  2017-06     Project Manager  Median Base Pay
# 4  National      Job Title  2017-06       Store Manager  Median Base Pay
#
#      Value    YoY  mnth    yr
# 0  85880.0  0.028     6  2017
# 1  67889.0  0.026     6  2017
# 2  71306.0  0.006     6  2017
# 3  72571.0  0.004     6  2017
# 4  48199.0  0.028     6  2017

# %% [markdown]
# <h2>Monthly Rent in the Ten Cities</h2>

# %%
# Monthly Rent for a 1 Bedroom Apartment in the ten cities
plt.figure(figsize=(8,5))  
ax = plt.gca() 
cost_of_living_df.plot(kind='bar',y='Apartment (1 bedroom) in City Centre',
                       label='City Center', color='b',ax=ax)
cost_of_living_df.plot(kind='bar',y='Apartment (1 bedroom) Outside of Centre',
                       label='Outside of City Center', color='lightblue',ax=ax)
plt.xlabel("City")
plt.ylabel("Dollars")
plt.xticks(rotation=45)
plt.legend(loc='center left', bbox_to_anchor=(0, 0.9))
ax.yaxis.grid(linewidth=0.5)
title = "Monthly Rent for a 1 Bedroom Apartment"
plt.title(title)
plt.savefig(f"{output_folder}/{title}.png", dpi=300, bbox_inches = "tight")
plt.show()

# %%
# Monthly Rent for a 3 Bedroom Apartment in the ten cities
plt.figure(figsize=(8,5))  
ax = plt.gca()
cost_of_living_df.plot(kind='bar',y='Apartment (3 bedrooms) in City Centre',
                       label='City Center', color='b',ax=ax)
cost_of_living_df.plot(kind='bar',y='Apartment (3 bedrooms) Outside of Centre',
                       label="Outside of City Center", color='lightblue',ax=ax)
plt.xlabel("City")
plt.xticks(rotation=45)
plt.ylabel("Dollars")
plt.legend(loc='center left', bbox_to_anchor=(0, 0.9))
ax.yaxis.grid(linewidth=0.5)
title = "Monthly Rent for a 3 Bedroom Apartment"
plt.title(title)
plt.savefig(f"{output_folder}/{title}.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# <h2>Average Monthly Net Salary (After Tax) as Reported from Numbeo</h2>

# %%
# Average Monthly Net Salary (After Tax)
cost_of_living_df.plot(kind='bar',y='Average Monthly Net Salary (After Tax)',
                       color='lightgreen',legend=False)
plt.ylabel("Dollars")
plt.xticks(rotation=45)
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(axis='y',linewidth=0.5)
title="Average Monthly Net Salary (After Tax)"
plt.title(title)
plt.savefig(f"{output_folder}/{title}.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# <h2>Glassdoor Median Base Annual Salary</h2>

# %%
# Add a column that has monthly salary based on annual salary
glassdoor_job_title_df["Monthly"] = glassdoor_job_title_df["Value"]/12
# Created a column with Date object for plotting purposes
glassdoor_job_title_df['Date'] = [datetime.strptime(month, '%Y-%m') for month in glassdoor_job_title_df['Month']]
glassdoor_job_title_df.head()
# Out:
#       Metro Dimension Type    Month           Dimension          Measure  \
# 0  National      Job Title  2017-06   Software Engineer  Median Base Pay
# 1  National      Job Title  2017-06  Programmer Analyst  Median Base Pay
# 2  National      Job Title  2017-06          Consultant  Median Base Pay
# 3  National      Job Title  2017-06     Project Manager  Median Base Pay
# 4  National      Job Title  2017-06       Store Manager  Median Base Pay
#
#      Value    YoY  mnth    yr      Monthly       Date
# 0  85880.0  0.028     6  2017  7156.666667 2017-06-01
# 1  67889.0  0.026     6  2017  5657.416667 2017-06-01
# 2  71306.0  0.006     6  2017  5942.166667 2017-06-01
# 3  72571.0  0.004     6  2017  6047.583333 2017-06-01
# 4  48199.0  0.028     6  2017  4016.583333 2017-06-01

# %%
# Median base salary from 2017-06 to 2019-02
#glassdoor_job_title_df["Month"].unique()

# %%
# Job titles in the Glassdoor data set
glassdoor_job_title_df["Dimension"].unique()
# Out:
# array(['Software Engineer', 'Programmer Analyst', 'Consultant',
#        'Project Manager', 'Store Manager', 'Business Analyst', 'Cashier',
#        'Financial Analyst', 'Administrative Assistant', 'Accountant',
#        'Sales Representative', 'Professor', 'Registered Nurse',
#        'Marketing Manager', 'Operations Manager', 'Product Manager',
#        'Sales Manager', 'Teacher', 'Bank Teller',
#        'Customer Service Manager', 'Physical Therapist',
#        'Mechanical Engineer', 'Recruiter', 'Design Engineer',
#        'Pharmacy Technician', 'Graphic Designer', 'Web Developer',
#        'Business Development Manager', 'Data Scientist', 'Buyer',
#        'Data Analyst', 'Electrical Engineer', 'Attorney',
#        'Human Resources Manager', 'Technician', 'Restaurant Cook',
#        'Production Manager', 'Manufacturing Engineer',
#        'Retail Key Holder', 'Paralegal', 'Java Developer',
#        'Warehouse Associate', 'Property Manager', 'Producer',
#        'Quality Engineer', 'Operations Analyst', 'Medical Assistant',
#        'Tax Manager', 'Technical Editor', 'Truck Driver',
#        'Insurance Agent', 'Medical Technologist', 'Field Engineer',
#        'Machine Operator', 'Communications Manager',
#        'Construction Laborer', 'Emergency Medical Technician',
#        'Web Designer', 'Maintenance Worker', 'Barista', 'Bartender',
#        'Civil Engineer', 'Claims Adjuster', 'Certified Nursing Assistant',
#        'Customer Service Representative', 'Delivery Driver',
#        'Financial Advisor', 'Licensed Practical Nurse', 'Loan Officer',
#        'Maintenance Technician', 'Material Handler', 'Network Engineer',
#        'Office Manager', 'Pharmacist', 'Process Engineer',
#        'Program Manager', 'Research Assistant', 'Restaurant Manager',
#        'Security Officer', 'Server', 'Solutions Architect',
#        'Systems Engineer', 'Technical Support', 'UX Designer',
#        'IT Manager'], dtype=object)

# %%
# Number of job titles
#print("There's {0} job titles in the Glassdoor dataset.".format(glassdoor_job_title_df["Dimension"].nunique()))

# %%
# Grouped by year and job titles and sorted median base pay by location in descending order
#year_job_location_df = glassdoor_job_title_df.groupby(["yr","Dimension"]).apply(lambda x: (x.groupby('Metro')
#                                       .mean()
#                                       .sort_values('Value', ascending=False))
#                                      .head(11))['Value']

# %%
# Glassdoor salary data for 2019 (Most recent)
glassdoor_job_title_2019 = glassdoor_job_title_df[glassdoor_job_title_df["yr"]==2019]

# # Display top 5 highest median base salary in each city
# glassdoor_job_title_2019.groupby("Metro").apply(lambda x: (x.groupby('Dimension')
#                                        .mean()
#                                        .sort_values('Value', ascending=False))
#                                       .head(5))['Value']
# # Display 5 lowest median base salary in each city
# glassdoor_job_title_2019.groupby("Metro").apply(lambda x: (x.groupby('Dimension')
#                                        .mean()
#                                        .sort_values('Value', ascending=False))
#                                       .tail(5))['Value']

# %% [markdown]
# <h1>Distribution of Median Base Annual Salary by Select Cities</h1>
# <h3>Let's do a 4 way comparison cost-of-living comparison. From the list below, pick 3 cities you're interested in. We'll include national information for you as well</h3>

# %%
#City options to choose from
cities_df = pd.DataFrame(glassdoor_job_title_df["Metro"].unique())
cities_df
# Out:
#                 0
# 0        National
# 1         Atlanta
# 2   New York City
# 3     Los Angeles
# 4    Philadelphia
# 5         Houston
# 6         Seattle
# 7   San Francisco
# 8         Chicago
# 9          Boston
# 10  Washington DC

# %%
select_cities = ["National"]
select_cities.append(input("What's the first city you're interested in? "))
select_cities.append(input("And the second? "))
select_cities.append(input("Final city? "))
# Out:
# What's the first city you're interested in? Chicago
# And the second? San Francisco
# Final city? Philadelphia

# %%
#cities = glassdoor_job_title_2019["Metro"].unique()
# select_cities = ["Chicago","San Francisco","Philadelphia","National"]
plt.figure(figsize=(8,5))   
print("Location\tMin\tMedian\tMax\t\tRange")
for city in select_cities:
#    subset = glassdoor_job_title_df[glassdoor_job_title_df['Metro'] == city]
    subset = glassdoor_job_title_2019[glassdoor_job_title_2019['Metro'] == city]
    #descr_stat = subset['Value'].describe()
    print(f"{city} \t{subset['Value'].min()}\t{subset['Value'].median()}\t{subset['Value'].max()}\t{subset['Value'].max()-subset['Value'].min()}")
    sns.distplot(subset['Value'], hist = False, kde = True,
                 kde_kws = {'linewidth': 3},
                 label = city)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), title = 'Cities')
title = 'Distribution of Median Base Annual Salary by City'
plt.xlabel('Salary')
plt.ylabel('Density')

# sns.distplot(glassdoor_job_title_2019['Value'], hist=True, kde=True, 
#              bins=int(180/5), color = 'blue', 
#              hist_kws={'edgecolor':'black'},
#              kde_kws={'linewidth': 2})
plt.title(title)
plt.savefig(f"{output_folder}/{title}.png", dpi=300, bbox_inches = "tight")
plt.show()
# Out:
# Location	Min	Median	Max		Range
# National 	25412.0	54165.5	128166.0	102754.0
# Chicago 	26494.0	61200.5	123164.0	96670.0
# San Francisco 	31741.0	75125.5	150572.0	118831.0
# Philadelphia 	24285.0	59877.0	122172.0	97887.0

# %% [markdown]
# <h1>Distribution of Median Base Annual Salary by Job Title</h1>
# <h3>Now let's compare some job titles. The list of job titles is below. Pick up to 5 job titles. If you don't want to pick 5, just hit "enter" when you're prompted for another title.</h3>

# %%
pd.set_option('display.max_rows', 100)
#create list of job titles for people to choose from
job_titles = pd.DataFrame(glassdoor_job_title_df["Dimension"].unique())
job_titles = job_titles.rename(columns={0:"Job Titles"})
job_titles.sort_values(["Job Titles"],inplace = True)
job_titles.reset_index(drop=True,inplace = True)
job_titles
# Out:
#                          Job Titles
# 0                        Accountant
# 1          Administrative Assistant
# 2                          Attorney
# 3                       Bank Teller
# 4                           Barista
# 5                         Bartender
# 6                  Business Analyst
# 7      Business Development Manager
# 8                             Buyer
# 9                           Cashier
# 10      Certified Nursing Assistant
# 11                   Civil Engineer
# 12                  Claims Adjuster
# 13           Communications Manager
# 14             Construction Laborer
# 15                       Consultant
# 16         Customer Service Manager
# 17  Customer Service Representative
# 18                     Data Analyst
# 19                   Data Scientist
# 20                  Delivery Driver
# 21                  Design Engineer
# 22              Electrical Engineer
# 23     Emergency Medical Technician
# 24                   Field Engineer
# 25                Financial Advisor
# 26                Financial Analyst
# 27                 Graphic Designer
# 28          Human Resources Manager
# 29                       IT Manager
# 30                  Insurance Agent
# 31                   Java Developer
# 32         Licensed Practical Nurse
# 33                     Loan Officer
# 34                 Machine Operator
# 35           Maintenance Technician
# 36               Maintenance Worker
# 37           Manufacturing Engineer
# 38                Marketing Manager
# 39                 Material Handler
# 40              Mechanical Engineer
# 41                Medical Assistant
# 42             Medical Technologist
# 43                 Network Engineer
# 44                   Office Manager
# 45               Operations Analyst
# 46               Operations Manager
# 47                        Paralegal
# 48                       Pharmacist
# 49              Pharmacy Technician
# 50               Physical Therapist
# 51                 Process Engineer
# 52                         Producer
# 53                  Product Manager
# 54               Production Manager
# 55                        Professor
# 56                  Program Manager
# 57               Programmer Analyst
# 58                  Project Manager
# 59                 Property Manager
# 60                 Quality Engineer
# 61                        Recruiter
# 62                 Registered Nurse
# 63               Research Assistant
# 64                  Restaurant Cook
# 65               Restaurant Manager
# 66                Retail Key Holder
# 67                    Sales Manager
# 68             Sales Representative
# 69                 Security Officer
# 70                           Server
# 71                Software Engineer
# 72              Solutions Architect
# 73                    Store Manager
# 74                 Systems Engineer
# 75                      Tax Manager
# 76                          Teacher
# 77                 Technical Editor
# 78                Technical Support
# 79                       Technician
# 80                     Truck Driver
# 81                      UX Designer
# 82              Warehouse Associate
# 83                     Web Designer
# 84                    Web Developer

# %%
job_titles = []
job_titles.append(input("What's the first job you're interested in? "))
job_titles.append(input("And the second? "))
job_titles.append(input("Third? "))
job_titles.append(input("Fourth? "))
job_titles.append(input("Final? "))
# Out:
# What's the first job you're interested in? Data Scientist
# And the second? Data Analyst
# Third? Pharmacist
# Fourth? Bartender
# Final? Registered Nurse

# %%
#job_titles = glassdoor_job_title_2019["Dimension"].unique()
#job_titles = ["Data Scientist","Data Analyst","Pharmacist","Bartender","Registered Nurse"]

plt.figure(figsize=(8,5))
print("Job Title \t\tMin\t\tMedian\t\tMax\t\tRange")
for job in job_titles:
#    subset = glassdoor_job_title_df[glassdoor_job_title_df['Dimension'] == job]
    subset = glassdoor_job_title_2019[glassdoor_job_title_2019['Dimension'] == job]
    print(f"{job:15} \t{subset['Value'].min():8}\t{subset['Value'].median():8}\t{subset['Value'].max():8}\t{subset['Value'].max()-subset['Value'].min()}")
    sns.distplot(subset['Value'], hist = False, kde = True,
                 kde_kws = {'linewidth': 3},
                 label = job)
    
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), title = 'Job Titles')
title = 'Distribution of Median Base Annual Salary by Job Title'
plt.xlabel('Salary')
plt.ylabel('Density')

# sns.distplot(glassdoor_job_title_2019['Value'], hist=True, kde=True, 
#              bins=int(180/5), color = 'blue', 
#              hist_kws={'edgecolor':'black'},
#              kde_kws={'linewidth': 2})
plt.title(title)
plt.savefig(f"{output_folder}/{title}.png", dpi=300, bbox_inches = "tight")
plt.show()
# Out:
# Job Title 		Min		Median		Max		Range
# Data Scientist  	 95765.0	109691.0	139799.0	44034.0
# Data Analyst    	 60820.0	 71915.5	 92107.0	31287.0
# Pharmacist      	113832.0	123954.0	145860.0	32028.0
# Bartender       	 33169.0	 37151.0	 42979.0	9810.0
# Registered Nurse 	 66477.0	 74529.5	117899.0	51422.0

# %%
# Grouped by Job Title and by Location
df_2019 = glassdoor_job_title_2019.groupby(["Dimension"]).apply(lambda x: (x.groupby('Metro')
                                      .mean())
                                      .head(11))['Monthly']

# %% [markdown]
# <h2>Salary and Cost of Living Analysis for a Job Title of Interest</h2>
# <h4> Pick a job title of interest. Refer above if you need a list!</h4>

# %%
job_title_interest=input("What job are you interested in? ")
# Out:
# What job are you interested in? Data Scientist

# %%
#national = df_2019[job_title_interest]['National']
df_2019_cities = df_2019[job_title_interest].drop("National")
#cost_of_living_df["Apartment (1 bedroom) in City Centre"]
rent_percent = cost_of_living_df["Apartment (1 bedroom) in City Centre"]/df_2019_cities
rent_percent_out = cost_of_living_df["Apartment (1 bedroom) Outside of Centre"]/df_2019_cities
rent_percent = rent_percent.append(rent_percent_out)

# %%
#rent_percent

# %%
plt.figure(figsize=(8,5))
ax = plt.gca()
df_2019_cities.plot(kind='bar',y=('Salary for {0}').format(job_title_interest),
                                 #label =('Monthly Salary for {0}').format(job_title_interest), 
                    label = "", color='lightgreen',ax=ax)
cost_of_living_df.plot(kind='bar',y='Apartment (1 bedroom) in City Centre',
                       label = "City Center", color='b',ax=ax)
cost_of_living_df.plot(kind='bar',y='Apartment (1 bedroom) Outside of Centre',
                       label = "Outside City Center", color='lightblue',ax=ax)
plt.xlabel("City")
plt.xticks(rotation=45)
plt.ylabel("Dollars")
plt.ylim(0,df_2019_cities.max()+1000)
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(loc='center left', bbox_to_anchor=(0, 0.9))
ax.yaxis.grid(linewidth=0.5)
#ax.get_children()[2].set_color('green')

cnt = 0
rects = ax.patches[10:32]
labels = rent_percent
for rect, label in zip(rects, labels):
    height = rect.get_height()
    if cnt < 10:
        ax.text(rect.get_x() + rect.get_width() / 2, height, '{:.0%}'.format(label),
            ha='center', va='bottom')
    else:
        ax.text(rect.get_x() + rect.get_width() / 2, height/3, '{:.0%}'.format(label),
           ha='center', va='center')
    cnt = cnt +1
title = "Monthly Rent for a 1 Bedroom Apartment for a {0}".format(job_title_interest)
plt.title(title)
plt.savefig(f"{output_folder}/{title}.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# <h2>Median Base Annual Salary over Time for a Job Title of Interest</h2>
# <h4>If you want to examine a new job title, go back up and select what interests you! Otherwise we will continue with the single job title you selected in the previous input</h4>

# %%
#timeseries for <job title> 
job_df = glassdoor_job_title_df[glassdoor_job_title_df['Dimension']==job_title_interest]

#plot
plt.figure(figsize=(8,5))
fig, ax = plt.subplots()
for metro in select_cities:
    df = job_df[job_df["Metro"]==metro]
    plt.plot(df["Date"],df["Value"],label=metro)

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("Date")
plt.xticks(rotation=45)
plt.xlim(min(df["Date"]),max(df["Date"]))
plt.ylabel("Dollars")
plt.grid(axis='y',linewidth=0.5)
title = "Median Base Annual Salary for {0} over Time".format(job_title_interest)
plt.title(title)
#plt.tight_layout()
plt.savefig(f"{output_folder}/{title}.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# <h2>Top 5 Job Titles with Highest Median Annual Base Pay by Location</h2>
# <h4>Pick a city you're interested in! If you need the list of cities, refer above</h4>

# %%
# top five job titles with highest median base pay
top_five = glassdoor_job_title_df.groupby(["Metro","yr"]).apply(lambda x: (x.groupby('Dimension')
                                      .mean()
                                      .sort_values('Value', ascending=False))#)['Value']
                                     .head(5))['Value']

# %%
city_highest = input("What city are you interested in? ")
# Out:
# What city are you interested in? Chicago

# %%
# top five job titles with highest median base pay in 2017-2019
top_five[city_highest]
# Out:
# yr    Dimension
# 2017  Pharmacist             120487.285714
#       Solutions Architect    109848.857143
#       Attorney               106832.714286
#       Tax Manager            103066.571429
#       Data Scientist          99965.857143
# 2018  Pharmacist             120629.416667
#       Attorney               113901.666667
#       Solutions Architect    113249.916667
#       Tax Manager            104378.833333
#       Data Scientist         103068.333333
# 2019  Pharmacist             121928.000000
#       Solutions Architect    116839.500000
#       Attorney               112117.000000
#       Data Scientist         104176.500000
#       Tax Manager            103218.000000
# Name: Value, dtype: float64

# %% [markdown]
# <h2>Average Median Base Salary for a Job Title based on Location</h2>
# <h4>If you want to examine a new city, go back up and select what interests you! Otherwise we will continue with the single city you selected in the previous input</h4>

# %%
# Average median base salary for <job title> in <year> 
year_interest = 2019

# Average median base pay for listed job titles grouped by year and city\
job_year_location = glassdoor_job_title_df.groupby(["Dimension","yr","Metro"])['Value'].mean()
#job_year_location

national = job_year_location[job_title_interest][year_interest]['National']
job_year_location_new = job_year_location[job_title_interest][year_interest].drop('National')

plt.figure(figsize=(8,5))
job_year_location_new.plot(kind="bar",color='lightgreen')
plt.xlabel("City")
plt.xticks(rotation=45)
plt.ylabel("Dollars")
plt.hlines(national,xmin=-1,xmax=10,colors='r',linestyles='dashed')
plt.grid(axis='y',linewidth=0.5)
title = "Average Median Base Salary for {0} in {1}".format(job_title_interest,year_interest)
plt.title(title)
plt.tight_layout()
plt.savefig(f"{output_folder}/{title}.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# <h1>Compare the Cost of Living for Two Cities</h1>
# <h4>But how do two cities stack up to each other. Let's find out - pick two!</h4>
# <h7>Need the city list again? Scroll back up!</h7>

# %%
cityA = input("What's the first city you're interested in?")
cityB = input("What's the second?")
# Out:
# What's the first city you're interested in?Chicago
# What's the second?San Francisco

# %%
# cityA_2019 = glassdoor_job_title_2019[glassdoor_job_title_2019['Metro']==cityA]
# cityA_201901 = cityA_2019[cityA_2019['Month']=="2019-01"]
# cityB_2019 = glassdoor_job_title_2019[glassdoor_job_title_2019['Metro']==cityB]
# cityB_201901 = cityB_2019[cityB_2019['Month']=="2019-01"]
#print(cityA_201901['Value'].mean())
#print(cityB_201901['Value'].mean())
# compares the salaries for two cities based on the 85 job titles
#stats.ttest_rel(cityA_201901['Value'],cityB_201901['Value'])

# %%
# dataframe that maps the city name to its row number
get_city_row = pd.DataFrame({'City' : cost_of_living_df.index, 
    'Index' : pd.Series(np.arange(0,10))} )
get_city_row = get_city_row.set_index('City')
get_city_row = get_city_row.T

# %%
# gets the row number of the cities of interest
cityA_ind = get_city_row[cityA][0]
cityB_ind = get_city_row[cityB][0]

# %%
#cost_of_living_df.columns
# compares across all the variables of cost of living
#stats.ttest_rel(cost_of_living_df.iloc[cityA_ind].values, cost_of_living_df.iloc[cityB_ind].values)

# %%
#print(cost_of_living_df.iloc[cityA_ind,47:52].values.mean())
#print(cost_of_living_df.iloc[cityB_ind,47:52].values.mean())

# %%
# compares the rent and apartment price variables of cost of living
housing_t, housing_p = stats.ttest_rel(cost_of_living_df.iloc[cityA_ind,47:52].values, cost_of_living_df.iloc[cityB_ind,47:52].values)

# compares the restaurant variables of cost of living
restaurant_t, restaurant_p = stats.ttest_rel(cost_of_living_df.iloc[cityA_ind,0:8].values, cost_of_living_df.iloc[cityB_ind,0:8].values)

# compares the food/market variables of cost of living
groceries_t, groceries_p = stats.ttest_rel(cost_of_living_df.iloc[cityA_ind,8:27].values, cost_of_living_df.iloc[cityB_ind,8:27].values)

# compares the transportation variables of cost of living
transportation_t, transportation_p = transportation_t, transportation_p = stats.ttest_rel(cost_of_living_df.iloc[cityA_ind,28:35].values, cost_of_living_df.iloc[cityB_ind,28:35].values)

# compares the monthly utilities
utilities_t, utilities_p = stats.ttest_rel(cost_of_living_df.iloc[cityA_ind,35:38].values, cost_of_living_df.iloc[cityB_ind,35:38].values)

# compares the sports and leisure variables
leisure_t, leisure_p = stats.ttest_rel(cost_of_living_df.iloc[cityA_ind,38:41].values, cost_of_living_df.iloc[cityB_ind,38:41].values)

# compares the childcare variables
childcare_t, childcare_p = stats.ttest_rel(cost_of_living_df.iloc[cityA_ind,41:43].values, cost_of_living_df.iloc[cityB_ind,41:43].values)

# compares the clothings and accessories variables
clothing_t, clothing_p = stats.ttest_rel(cost_of_living_df.iloc[cityA_ind,43:47].values, cost_of_living_df.iloc[cityB_ind,43:47].values)

# %%
# Place test results into a data frame
city_compare_vars=["Housing","Restaurants","Groceries","Transportation","Utilities","Leisure","Childcare","Clothing"]
city_compare_tests = pd.DataFrame(np.array([[housing_t, housing_p], 
                                             [restaurant_t, restaurant_p],
                                             [groceries_t, groceries_p],
                                             [transportation_t, transportation_p],
                                             [utilities_t, utilities_p], 
                                             [leisure_t, leisure_p],
                                             [childcare_t, childcare_p], 
                                             [clothing_t, clothing_p]]),
                                             columns=["statistic","p-value"], index=city_compare_vars)
city_compare_tests
# Out:
#                 statistic   p-value
# Housing         -5.922686  0.004071
# Restaurants     -1.323920  0.227124
# Groceries       -2.228144  0.038862
# Transportation  -1.365496  0.221072
# Utilities        0.381021  0.739854
# Leisure         -0.769546  0.522031
# Childcare       -8.500211  0.074552
# Clothing        -2.840439  0.065623

# %%
cityA_housing_mean = cost_of_living_df.iloc[cityA_ind,47:52].values.mean()
cityA_restaurants = 4*cost_of_living_df.iloc[cityA_ind,0:8].values.sum()
cityA_groceries = 4*cost_of_living_df.iloc[cityA_ind,8:27].values.sum()
cityA_transportation = cost_of_living_df.iloc[cityA_ind,28:33].values.mean()
cityA_utilities_sum = cost_of_living_df.iloc[cityA_ind,35:38].values.sum()
cityA_leisure_sum = cost_of_living_df.iloc[cityA_ind,38:41].values.sum()
cityA_childcare_mean = cost_of_living_df.iloc[cityA_ind,41:43].values.mean()
#cityA_clothing_sum = cost_of_living_df.iloc[cityA_ind,43:47].values.sum()

cityB_housing_mean = cost_of_living_df.iloc[cityB_ind,47:52].values.mean()
cityB_restaurants = 4*cost_of_living_df.iloc[cityB_ind,0:8].values.sum()
cityB_groceries = 4*cost_of_living_df.iloc[cityB_ind,8:27].values.sum()
cityB_transportation = cost_of_living_df.iloc[cityB_ind,28:33].values.mean()
cityB_utilities_sum = cost_of_living_df.iloc[cityB_ind,35:38].values.sum()
cityB_leisure_sum = cost_of_living_df.iloc[cityB_ind,38:41].values.sum()
cityB_childcare_mean = cost_of_living_df.iloc[cityB_ind,41:43].values.mean()
#cityB_clothing_sum = cost_of_living_df.iloc[cityB_ind,43:47].values.sum()

# %%
index_monthly=["Housing","Restaurants","Groceries","Transportation","Utilities","Leisure","Childcare"]

# %%
city_compare_living = pd.DataFrame(np.array([[cityA_housing_mean, cityB_housing_mean], 
                                             [cityA_restaurants, cityB_restaurants],
                                             [cityA_groceries, cityB_groceries],
                                             [cityA_transportation, cityB_transportation],
                                             [cityA_utilities_sum, cityB_utilities_sum], 
                                             [cityA_leisure_sum, cityB_leisure_sum],
                                             [cityA_childcare_mean, cityB_childcare_mean]]), 
#                                             [cityA_clothing_mean, cityB_clothing_mean]]),
                                             columns=[cityA,cityB], index=index_monthly)

# %%
#city_compare_living
explode= (0.05,0.05,0.05,0.05,0.05,0.05,0.05)

# %%
plt.pie(city_compare_living[cityA].values,explode=explode,
        autopct="%1.1f%%",labels=city_compare_living.index,shadow=False,
       startangle=90, pctdistance=1.25, labeldistance=1.45)
centre_circle = plt.Circle((0,0),0.70,fc='white')
title = f"Cost of Living {cityA}"
plt.title(title)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.savefig(f"{output_folder}/{title}.png", dpi=300)
plt.show()

# %%
plt.pie(city_compare_living[cityB].values,explode=explode,
        autopct="%1.1f%%",labels=city_compare_living.index,shadow=False,
       startangle=90, pctdistance=1.25, labeldistance=1.45)
centre_circle = plt.Circle((0,0),0.70,fc='white')
title = f"Cost of Living {cityB}"
plt.title(title)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.savefig(f"{output_folder}/{title}.png", dpi=600)
plt.show()

# %%
#city_compare_living.plot(kind="bar")
# explode= (0.05,0.05,0.05,0.05,0.05,0.05,0.05)
# f, (ax1,ax2) = plt.subplots(1,2,sharey=True)
# ax1.pie(city_compare_living[cityA].values,explode=explode,
#         autopct="%1.1f%%",labels=city_compare_living.index,shadow=True,
#        startangle=90, pctdistance=0.85)
# centre_circle = plt.Circle((0,0),0.70,fc='white')

# fig = plt.gcf()
# fig.gca().add_artist(centre_circle)

# ax2.pie(city_compare_living[cityB].values,explode=explode,
#         autopct="%1.1f%%",labels=city_compare_living.index,shadow=True,
#        startangle=90, pctdistance=0.5)
# #plt.tight_layout()
# plt.show()

# %%
# plt.pie(city_compare_living[cityA].values,explode=explode,
#         autopct="%1.1f%%",labels=city_compare_living.index,shadow=True,
#        startangle=90, pctdistance=1.25, labeldistance=1.45)
# centre_circle = plt.Circle((0,0),0.70,fc='white')
# fig = plt.gcf()
# fig.gca().add_artist(centre_circle)
# plt.show()

# %%
# Alternative plotting method
# x_axis = np.arange(len(cost_of_living_df.index))
# y_values = cost_of_living_df['Apartment (1 bedroom) in City Centre'].astype(float)
# plt.bar(x_axis, y_values, 
#         color='b', alpha=0.5, align="center")
# tick_locations = [value for value in x_axis]
# plt.xticks(tick_locations, cost_of_living_df.index, rotation="vertical")
# plt.ylim(0, max(y_values)+500)
# plt.xlabel("City")
# plt.ylabel("Apartment (1 bedroom) in City Centre")
# plt.show()
